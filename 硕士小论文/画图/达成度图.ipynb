# %% [markdown]
# # 邢老师目标1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置中文字体，确保中文正常显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]

# 学生达成度数据（源自Excel文档）
scores = [
    0.64, 0.7, 0.78, 0.63, 0.57, 0.85, 0.79, 0.71, 0.84, 0.72,
    0.77, 0.84, 0.86, 0.74, 0.64, 0.87, 0.86, 0.85, 0.69, 0.82,
    0.88, 0.77, 0.82, 0.74, 0.83, 0.76, 0.61, 0.81, 0.64, 0.63,
    0.76, 0.65, 0.7, 0.65, 0.8, 0.82, 0.64, 0.7, 0.68, 0.58,
    0.69, 0.73, 0.7, 0.67, 0.68, 0.75, 0.75, 0.84, 0.76, 0.89,
    0.77, 0.82, 0.69, 0.71, 0.77, 0.88, 0.83, 0.7, 0.74, 0.75,
    0.73, 0.76, 0.56, 0.74, 0.84, 0.82, 0.85, 0.8, 0.72, 0.8,
    0.68, 0.73, 0.82, 0.69, 0.75, 0.63, 0.57, 0.64, 0.57, 0.85,
    0.75, 0.83, 0.8, 0.6, 0.66, 0.64, 0.78
]

student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10  # 76 → 80

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)                # 横轴范围扩展至80（适配76名学生）
plt.ylim(0, 1.0)                      # 纵轴范围0-1.0
plt.xticks(np.arange(0, max_xtick + 1, 10))  # 每10个学生显示一个刻度（0,10,...,80）
plt.yticks(np.arange(0, 1.01, 0.1))          # 纵轴每0.1显示刻度

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.65, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# ...

# %% [markdown]
# # 邢老师目标2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置中文字体，确保中文正常显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]

# 学生达成度数据（源自Excel文档）
scores = [0.66, 0.71, 0.75, 0.66, 0.59, 0.83, 0.78, 0.7, 0.82, 0.73, 0.76, 0.82, 0.84, 0.75, 0.64, 0.85, 0.85, 0.84, 0.71, 0.81, 0.86, 0.76, 0.81, 0.74, 0.79, 0.78, 0.63, 0.77, 0.65, 0.65, 0.77, 0.67, 0.72, 0.68, 0.78, 0.81, 0.65, 0.69, 0.67, 0.59, 0.71, 0.72, 0.71, 0.68, 0.69, 0.74, 0.75, 0.81, 0.76, 0.88, 0.77, 0.81, 0.69, 0.71, 0.78, 0.86, 0.83, 0.7, 0.74, 0.76, 0.71, 0.76, 0.61, 0.76, 0.83, 0.81, 0.82, 0.77, 0.71, 0.78, 0.7, 0.75, 0.79, 0.68, 0.75, 0.64, 0.6, 0.66, 0.61, 0.83, 0.76, 0.82, 0.8, 0.62, 0.68, 0.66, 0.78]

student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10  # 76 → 80

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)                # 横轴范围扩展至80（适配76名学生）
plt.ylim(0, 1.0)                      # 纵轴范围0-1.0
plt.xticks(np.arange(0, max_xtick + 1, 10))  # 每10个学生显示一个刻度（0,10,...,80）
plt.yticks(np.arange(0, 1.01, 0.1))          # 纵轴每0.1显示刻度

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.65, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# ...

# %% [markdown]
# # 邢老师目标3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置中文字体，确保中文正常显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]

# 学生达成度数据（源自Excel文档）
scores = [0.66, 0.71, 0.75, 0.66, 0.59, 0.83, 0.78, 0.7, 0.82, 0.73, 0.76, 0.82, 0.84, 0.75, 0.64, 0.85, 0.85, 0.84, 0.71, 0.81, 0.86, 0.76, 0.81, 0.74, 0.79, 0.78, 0.63, 0.77, 0.65, 0.65, 0.77, 0.67, 0.72, 0.68, 0.78, 0.81, 0.65, 0.69, 0.67, 0.59, 0.71, 0.72, 0.71, 0.68, 0.69, 0.74, 0.75, 0.81, 0.76, 0.88, 0.77, 0.81, 0.69, 0.71, 0.78, 0.86, 0.83, 0.7, 0.74, 0.76, 0.71, 0.76, 0.61, 0.76, 0.83, 0.81, 0.82, 0.77, 0.71, 0.78, 0.7, 0.75, 0.79, 0.68, 0.75, 0.64, 0.6, 0.66, 0.61, 0.83, 0.76, 0.82, 0.8, 0.62, 0.68, 0.66, 0.78]
student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10  # 76 → 80

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)                # 横轴范围扩展至80（适配76名学生）
plt.ylim(0, 1.0)                      # 纵轴范围0-1.0
plt.xticks(np.arange(0, max_xtick + 1, 10))  # 每10个学生显示一个刻度（0,10,...,80）
plt.yticks(np.arange(0, 1.01, 0.1))          # 纵轴每0.1显示刻度

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.65, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# ...

# %% [markdown]
# # 西方经济学目标1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置中文字体，确保中文正常显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [0.63, 0.61, 0.59, 0.59, 0.58, 0.8, 0.64, 0.74, 0.81, 0.7, 0.66, 0.9, 0.84, 0.83, 0.84, 0.69, 0.7, 0.74, 0.69, 0.8, 0.82, 0.67, 0.82, 0.82, 0.72, 0.76, 0.86, 0.72, 0.79, 0.83, 0.76, 0.78, 0.81, 0.73, 0.79, 0.72, 0.71, 0.68, 0.6, 0.81, 0.61, 0.79, 0.59, 0.59, 0.63, 0.63, 0.83, 0.62, 0.7, 0.75, 0.69, 0.59, 0.61, 0.63, 0.63, 0.76, 0.73, 0.67, 0.8, 0.74, 0.72, 0.89, 0.59, 0.69, 0.62, 0.7, 0.61, 0.8, 0.72, 0.73, 0.7, 0.63, 0.72, 0.7, 0.66, 0.67, 0.58, 0.68, 0.72, 0.71, 0.75, 0.9, 0.74, 0.74, 0.8, 0.71, 0.68, 0.86, 0.75, 0.73, 0.78, 0.69, 0.83, 0.76, 0.73, 0.69, 0.64, 0.66, 0.69, 0.56, 0.74, 0.78, 0.64, 0.72, 0.74, 0.71, 0.67]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.6, color='red', linestyle='--', linewidth=2, label='期望值0.6')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.6', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# ...

# %% [markdown]
# # 西方经济学目标2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置中文字体，确保中文正常显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [0.65, 0.61, 0.61, 0.61, 0.61, 0.77, 0.64, 0.74, 0.79, 0.7, 0.66, 0.88, 0.83, 0.82, 0.81, 0.68, 0.7, 0.72, 0.7, 0.78, 0.79, 0.66, 0.79, 0.79, 0.72, 0.75, 0.84, 0.71, 0.77, 0.8, 0.75, 0.76, 0.78, 0.73, 0.78, 0.74, 0.71, 0.67, 0.6, 0.78, 0.58, 0.78, 0.61, 0.6, 0.65, 0.61, 0.8, 0.59, 0.72, 0.76, 0.69, 0.6, 0.59, 0.63, 0.64, 0.77, 0.74, 0.68, 0.8, 0.74, 0.72, 0.86, 0.62, 0.67, 0.63, 0.7, 0.62, 0.79, 0.7, 0.7, 0.69, 0.65, 0.71, 0.7, 0.67, 0.68, 0.61, 0.7, 0.73, 0.71, 0.73, 0.89, 0.73, 0.74, 0.8, 0.71, 0.68, 0.85, 0.75, 0.73, 0.76, 0.69, 0.81, 0.75, 0.72, 0.68, 0.64, 0.68, 0.66, 0.55, 0.74, 0.75, 0.66, 0.73, 0.74, 0.72, 0.68]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.6, color='red', linestyle='--', linewidth=2, label='期望值0.6')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.6', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# ...

# %% [markdown]
# # 西方经济学目标3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置中文字体，确保中文正常显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [0.65, 0.63, 0.61, 0.61, 0.62, 0.81, 0.66, 0.74, 0.82, 0.74, 0.67, 0.92, 0.83, 0.84, 0.83, 0.69, 0.73, 0.72, 0.71, 0.8, 0.8, 0.7, 0.8, 0.8, 0.75, 0.75, 0.85, 0.73, 0.8, 0.81, 0.78, 0.76, 0.8, 0.73, 0.77, 0.75, 0.73, 0.67, 0.61, 0.83, 0.64, 0.77, 0.61, 0.61, 0.67, 0.66, 0.8, 0.64, 0.71, 0.75, 0.7, 0.63, 0.63, 0.65, 0.65, 0.75, 0.7, 0.69, 0.79, 0.73, 0.73, 0.86, 0.61, 0.7, 0.65, 0.77, 0.63, 0.81, 0.7, 0.71, 0.71, 0.66, 0.75, 0.7, 0.69, 0.7, 0.62, 0.74, 0.74, 0.7, 0.74, 0.93, 0.73, 0.73, 0.83, 0.7, 0.67, 0.87, 0.74, 0.72, 0.75, 0.69, 0.84, 0.81, 0.76, 0.7, 0.64, 0.67, 0.69, 0.56, 0.73, 0.79, 0.66, 0.73, 0.73, 0.73, 0.7]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.6, color='red', linestyle='--', linewidth=2, label='期望值0.6')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.6', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'WenQuanYi Micro Hei' not found.
# findfont: Font family 'SimHei' not found.
# ...

# %% [markdown]
# # 房地产经济学目标1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.9, 0.94, 0.85, 0.83, 0.86, 0.92, 0.91, 0.88, 0.88, 0.95,
    0.96, 0.97, 0.86, 0.83, 0.82, 0.81, 0.95, 0.9, 0.91, 0.84,
    0.84, 0.88, 0.76, 0.87, 0.84, 0.8, 0.84, 0.83, 0.78, 0.81,
    0.8, 0.76, 0.84, 0.91, 0.96, 0.93, 0.92, 0.93, 0.95, 0.86,
    0.89, 0.89, 0.82, 0.82, 0.87, 0.81, 0.92, 0.82, 0.87, 0.87,
    0.86, 0.93, 0.83, 0.82, 0.82, 0.84, 0.84, 0.86, 0.77, 0.81,
    0.91, 0.96, 0.9, 0.84, 0.86, 0.84, 0.86, 0.84, 0.82
]
student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.75, color='red', linestyle='--', linewidth=2, label='期望值0.75')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.75)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.75', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# # 房地产经济学目标2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.85, 0.86, 0.78, 0.75, 0.82, 0.85, 0.84, 0.84, 0.84, 0.89,
    0.9, 0.92, 0.81, 0.79, 0.78, 0.77, 0.89, 0.84, 0.87, 0.77,
    0.77, 0.83, 0.7, 0.82, 0.77, 0.76, 0.79, 0.79, 0.75, 0.77,
    0.75, 0.73, 0.79, 0.84, 0.92, 0.87, 0.88, 0.89, 0.88, 0.81,
    0.84, 0.83, 0.79, 0.76, 0.83, 0.74, 0.88, 0.8, 0.83, 0.83,
    0.81, 0.87, 0.74, 0.79, 0.76, 0.76, 0.76, 0.81, 0.72, 0.75,
    0.87, 0.89, 0.83, 0.79, 0.81, 0.79, 0.81, 0.76, 0.79
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.75, color='red', linestyle='--', linewidth=2, label='期望值0.75')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.75)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.75', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# # 房地产经济学目标3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.91, 0.91, 0.81, 0.79, 0.86, 0.9, 0.88, 0.86, 0.86, 0.92,
    0.93, 0.95, 0.86, 0.83, 0.82, 0.81, 0.94, 0.86, 0.91, 0.81,
    0.81, 0.88, 0.76, 0.86, 0.81, 0.78, 0.83, 0.84, 0.79, 0.81,
    0.79, 0.76, 0.83, 0.88, 0.94, 0.9, 0.91, 0.92, 0.93, 0.82,
    0.88, 0.87, 0.82, 0.79, 0.84, 0.77, 0.9, 0.83, 0.84, 0.85,
    0.81, 0.92, 0.78, 0.81, 0.8, 0.79, 0.8, 0.82, 0.74, 0.77,
    0.92, 0.94, 0.87, 0.82, 0.82, 0.81, 0.84, 0.79, 0.82
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.75, color='red', linestyle='--', linewidth=2, label='期望值0.75')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.75', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# # 劳动目标1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.87, 0.76, 0.8, 0.79, 0.79, 0.86, 0.91, 0.85, 0.75, 0.89,
    0.89, 0.83, 0.81, 0.69, 0.74, 0.82, 0.85, 0.84, 0.69, 0.86,
    0.75, 0.8, 0.71, 0.75, 0.75, 0.69, 0.71, 0.89, 0.8, 0.89,
    0.68, 0.75, 0.74, 0.8, 0.89, 0.88, 0.87, 0.87, 0.8, 0.74,
    0.81, 0.9, 0.8, 0.8, 0.89, 0.77, 0.88, 0.81, 0.82, 0.83,
    0.8, 0.74, 0.69, 0.73, 0.65, 0.73, 0.67, 0.66, 0.66, 0.8,
    0.76, 0.76, 0.7, 0.75, 0.83, 0.76, 0.73, 0.76
]
student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# # 劳动目标2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.84, 0.74, 0.75, 0.73, 0.74, 0.82, 0.85, 0.78, 0.73, 0.82,
    0.82, 0.76, 0.76, 0.66, 0.71, 0.76, 0.82, 0.77, 0.67, 0.78,
    0.71, 0.74, 0.65, 0.7, 0.7, 0.67, 0.67, 0.82, 0.74, 0.85,
    0.64, 0.7, 0.71, 0.76, 0.81, 0.81, 0.84, 0.82, 0.76, 0.71,
    0.76, 0.85, 0.75, 0.75, 0.82, 0.74, 0.83, 0.76, 0.79, 0.76,
    0.75, 0.69, 0.67, 0.7, 0.63, 0.7, 0.66, 0.65, 0.65, 0.74,
    0.74, 0.74, 0.68, 0.71, 0.76, 0.72, 0.67, 0.72
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# # 劳动目标3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.88, 0.77, 0.82, 0.79, 0.81, 0.87, 0.89, 0.83, 0.76, 0.87,
    0.87, 0.8, 0.8, 0.71, 0.73, 0.84, 0.86, 0.81, 0.72, 0.82,
    0.76, 0.82, 0.7, 0.75, 0.75, 0.73, 0.73, 0.86, 0.8, 0.88,
    0.69, 0.75, 0.74, 0.8, 0.85, 0.85, 0.89, 0.86, 0.81, 0.73,
    0.81, 0.9, 0.81, 0.82, 0.86, 0.77, 0.87, 0.81, 0.84, 0.8,
    0.79, 0.75, 0.73, 0.75, 0.68, 0.73, 0.71, 0.7, 0.71, 0.77,
    0.79, 0.78, 0.73, 0.77, 0.8, 0.78, 0.73, 0.75
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 经济学基础1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.74, 0.73, 0.89, 0.77, 0.79, 0.76, 0.76, 0.82, 0.7, 0.86,
    0.81, 0.77, 0.86, 0.8, 0.76, 0.83, 0.72, 0.79, 0.8, 0.77,
    0.79, 0.81, 0.75, 0.79, 0.83, 0.79, 0.8, 0.92, 0.86, 0.85,
    0.87, 0.9, 0.66, 0.76, 0.72, 0.77, 0.77, 0.73, 0.66, 0.8,
    0.78, 0.81, 0.75, 0.71, 0.83, 0.77, 0.77, 0.77, 0.68, 0.78,
    0.85, 0.64, 0.75, 0.8, 0.69, 0.74, 0.8, 0.74, 0.76, 0.71,
    0.74, 0.8, 0.74, 0.77, 0.75, 0.68, 0.77, 0.86, 0.77, 0.71,
    0.67, 0.67, 0.73, 0.72, 0.76
]
student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 经济学基础2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.74, 0.74, 0.86, 0.77, 0.77, 0.77, 0.77, 0.79, 0.71, 0.85,
    0.83, 0.77, 0.84, 0.81, 0.77, 0.85, 0.71, 0.78, 0.81, 0.76,
    0.78, 0.82, 0.76, 0.77, 0.83, 0.77, 0.81, 0.91, 0.84, 0.82,
    0.86, 0.89, 0.68, 0.75, 0.72, 0.77, 0.77, 0.73, 0.66, 0.8,
    0.78, 0.8, 0.75, 0.73, 0.81, 0.77, 0.77, 0.75, 0.69, 0.77,
    0.83, 0.64, 0.75, 0.79, 0.67, 0.74, 0.77, 0.72, 0.74, 0.71,
    0.75, 0.78, 0.75, 0.77, 0.73, 0.69, 0.77, 0.87, 0.75, 0.71,
    0.69, 0.68, 0.74, 0.72, 0.76
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 经济学基础3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.76, 0.76, 0.88, 0.79, 0.79, 0.78, 0.78, 0.81, 0.74, 0.87,
    0.85, 0.78, 0.86, 0.83, 0.78, 0.87, 0.75, 0.81, 0.82, 0.79,
    0.81, 0.84, 0.77, 0.78, 0.85, 0.79, 0.81, 0.92, 0.85, 0.84,
    0.85, 0.93, 0.71, 0.77, 0.75, 0.79, 0.79, 0.74, 0.69, 0.81,
    0.79, 0.81, 0.76, 0.76, 0.83, 0.78, 0.8, 0.79, 0.72, 0.8,
    0.85, 0.69, 0.78, 0.79, 0.71, 0.75, 0.78, 0.76, 0.77, 0.74,
    0.76, 0.78, 0.76, 0.79, 0.75, 0.71, 0.79, 0.9, 0.76, 0.71,
    0.73, 0.71, 0.75, 0.75, 0.78
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 基础2 目标1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.75, 0.81, 0.81, 0.83, 0.81, 0.79, 0.81, 0.82, 0.78, 0.7,
    0.72, 0.82, 0.81, 0.76, 0.79, 0.84, 0.78, 0.81, 0.78, 0.73,
    0.82, 0.8, 0.82, 0.78, 0.79, 0.68, 0.73, 0.78, 0.77, 0.71,
    0.7, 0.75, 0.71, 0.84, 0.69, 0.74, 0.73, 0.73, 0.71, 0.78,
    0.78, 0.74, 0.78, 0.79, 0.8, 0.64, 0.76, 0.68, 0.8, 0.75,
    0.81, 0.8, 0.77, 0.72, 0.82, 0.8, 0.78, 0.74, 0.77, 0.75,
    0.8, 0.75, 0.62, 0.74, 0.75, 0.77, 0.68, 0.83, 0.85, 0.77,
    0.68, 0.67, 0.73, 0.78
]
student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 基础2 目标2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.76, 0.79, 0.81, 0.81, 0.79, 0.79, 0.8, 0.82, 0.76, 0.71,
    0.73, 0.81, 0.79, 0.75, 0.79, 0.84, 0.76, 0.81, 0.77, 0.73,
    0.81, 0.8, 0.79, 0.78, 0.8, 0.68, 0.72, 0.76, 0.76, 0.72,
    0.7, 0.75, 0.69, 0.82, 0.66, 0.76, 0.74, 0.74, 0.71, 0.77,
    0.77, 0.72, 0.76, 0.78, 0.79, 0.65, 0.77, 0.7, 0.79, 0.75,
    0.79, 0.78, 0.75, 0.72, 0.8, 0.8, 0.77, 0.72, 0.76, 0.74,
    0.79, 0.73, 0.62, 0.74, 0.75, 0.76, 0.67, 0.82, 0.85, 0.77,
    0.7, 0.68, 0.72, 0.78
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 基础2 目标3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.78, 0.84, 0.83, 0.83, 0.81, 0.8, 0.81, 0.83, 0.8, 0.74,
    0.75, 0.82, 0.8, 0.79, 0.8, 0.86, 0.81, 0.83, 0.79, 0.75,
    0.83, 0.83, 0.81, 0.79, 0.8, 0.7, 0.75, 0.79, 0.78, 0.72,
    0.74, 0.77, 0.71, 0.84, 0.73, 0.79, 0.75, 0.75, 0.76, 0.82,
    0.8, 0.77, 0.8, 0.8, 0.8, 0.67, 0.77, 0.73, 0.81, 0.79,
    0.8, 0.81, 0.79, 0.74, 0.82, 0.81, 0.83, 0.75, 0.8, 0.77,
    0.81, 0.77, 0.63, 0.76, 0.76, 0.76, 0.68, 0.84, 0.9, 0.77,
    0.71, 0.69, 0.73, 0.77
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 产经目标1

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.75, 0.8, 0.84, 0.84, 0.84, 0.75, 0.81, 0.89, 0.73, 0.87,
    0.75, 0.78, 0.77, 0.83, 0.64, 0.78, 0.79, 0.67, 0.76, 0.82,
    0.8, 0.8, 0.83, 0.82, 0.88, 0.91, 0.88, 0.8, 0.79, 0.85,
    0.75, 0.81, 0.75, 0.74
]
student_count = len(scores)  # 实际学生数量（此处为76）
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标1达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图1·课程目标1达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 产经目标2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.76, 0.77, 0.84, 0.8, 0.79, 0.77, 0.78, 0.83, 0.7, 0.86,
    0.83, 0.79, 0.87, 0.84, 0.75, 0.84, 0.74, 0.76, 0.79, 0.76,
    0.79, 0.82, 0.77, 0.79, 0.87, 0.81, 0.82, 0.87, 0.84, 0.84,
    0.87, 0.87, 0.69, 0.73
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标2达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.65)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图2·课程目标2达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
# 产经目标3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# 设置字体为系统默认的多语言字体
plt.rcParams["font.family"] = ["Arial Unicode MS", "sans-serif"]

# 学生达成度数据（源自之前生成的列表数据）
scores = [
    0.78, 0.79, 0.85, 0.81, 0.81, 0.79, 0.8, 0.85, 0.73, 0.88,
    0.84, 0.82, 0.88, 0.86, 0.75, 0.86, 0.77, 0.79, 0.79, 0.8,
    0.82, 0.84, 0.78, 0.81, 0.89, 0.82, 0.84, 0.9, 0.87, 0.85,
    0.86, 0.89, 0.73, 0.74
]
student_count = len(scores)  # 实际学生数量
student_ids = range(student_count)  # 学生序号从0开始

# 计算横轴最大刻度（最近的10的倍数）
max_xtick = math.ceil(student_count / 10) * 10

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制学生达成度散点（无折线，仅数据点）
plt.scatter(student_ids, scores, color='#1f77b4', s=30, label='学生达成度')

# 添加期望值0.65水平线（红色虚线，匹配截图风格）
plt.axhline(y=0.65, color='red', linestyle='--', linewidth=2, label='期望值0.65')

# 设置坐标轴范围与刻度（动态适配学生数量）
plt.xlim(0, max_xtick)
plt.ylim(0, 1.0)
plt.xticks(np.arange(0, max_xtick + 1, 10))
plt.yticks(np.arange(0, 1.01, 0.1))

# 设置标签与标题（贴合截图的"课程目标1达成度"描述）
plt.xlabel('学生序号', fontsize=12)
plt.ylabel('课程目标3达成度', fontsize=12)

# 添加网格线（截图风格的灰色虚线网格）
plt.grid(True, linestyle=':', color='gray', alpha=0.7)

# 在图表右侧添加期望值文本标注（红色，位置自动适配）
plt.text(max_xtick + 2, 0.6, '期望值0.65', color='red', va='center', ha='left', fontsize=12)

# 设置图表边框为灰色（匹配截图风格）
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_color('gray')

# 添加图表下方标题（匹配截图的"图1·课程目标1达成度分布图"）
plt.title('图3·课程目标3达成度分布图', y=-0.15, fontsize=14)

# 添加图例
plt.legend()

# 调整布局并显示
plt.tight_layout()
plt.show()
